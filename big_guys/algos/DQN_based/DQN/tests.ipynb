# %%
from RL.big_guys.algos.DQN_based.DQN.DQN import DQN
import matplotlib.pyplot as plt

# %%
# %%time
stats, agent = DQN("Boxing-v0", epochs=1,
                   eps_sched={"start": 0.9, "end": 0.05, "decay": 200})

plt.plot(stats.EpRet)
plt.show()
plt.plot(stats.EpLen)
plt.show()
plt.plot(agent.loss)
plt.show()
plt.plot(agent.eps)
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 3000/3000 [02:31<00:00, 19.80it/s]
# Wall time: 2min 35s

# %%
# %%time
stats, agent = DQN("Berzerk-v0", epochs=5, 
                   eps_sched={"start": 0.9, "end": 0.05, "decay": 200},
                   double=True)

plt.plot(stats.EpRet)
plt.show()
plt.plot(stats.EpLen)
plt.show()
plt.plot(agent.loss)
plt.show()
plt.plot(agent.eps)
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1500/1500 [00:33<00:00, 45.20it/s]
# Exception ignored in: <bound method SimpleImageViewer.__del__ of <gym.envs.classic_control.rendering.SimpleImageViewer object at 0x0000017C821C0DD8>>
# Traceback (most recent call last):
#   File "c:\users\daddu\appdata\local\programs\python\python36\lib\site-packages\gym\envs\classic_control\rendering.py", line 379, in __del__
#     self.close()
#   File "c:\users\daddu\appdata\local\programs\python\python36\lib\site-packages\gym\envs\classic_control\rendering.py", line 375, in close
#     self.window.close()
#   File "c:\users\daddu\appdata\local\programs\python\python36\lib\site-packages\pyglet\window\win32\__init__.py", line 299, in close
#     super(Win32Window, self).close()
#   File "c:\users\daddu\appdata\local\programs\python\python36\lib\site-packages\pyglet\window\__init__.py", line 823, in close
#     app.windows.remove(self)
# ...

# %%
# %%time
stats, agent = DQN("Berzerk-v0", epochs=5, 
                   eps_sched={"start": 0.9, "end": 0.05, "decay": 200},
                   dueling=True, start_steps=100)

plt.plot(stats.EpRet)
plt.show()
plt.plot(stats.EpLen)
plt.show()
plt.plot(agent.loss)
plt.show()
plt.plot(agent.eps)
plt.show()
# Out:
#  16%|████████████▌                                                                | 2437/15000 [01:28<11:40, 17.94it/s]
